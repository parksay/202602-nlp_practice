# %% [markdown]
# # 전처리 연습
# - tokenize
# - cleansing
# - normalization
# - stemming
# - lemmatization

# %% [markdown]
# 1. 데이터셋을 찾는다 (만들어져 있는 데이터셋이나 크롤링이나 상관없음
# 2. 전처리
#     2-1. 의미 있는 단어 단위로 단어장 만들기
#     2-2. corpus -> tokenize -> 정규화+cleansing -> 문장
